# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system = futures_system()
# Out:
# Configuring sim logging
# Private configuration '/Users/jasonli/Dev/FORKed repo/pysystemtrade/private/private_config.yaml' is missing or misconfigured; no problem if running in sim mode

# %%
print(system.get_instrument_list())
# Out:
# 2026-05-20 12:41:31 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2026-05-20 12:41:31 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2026-05-20 12:41:31 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# ['CORN', 'EUROSTX', 'MXP', 'SOFR', 'US10', 'V2X']
